# %% [markdown]
# ## Using NEXRAD data from Amazon Web Services

# %% [markdown]
# Amazon has a cloud storage solution called Simple Storage Service or S3. S3 is a distributed store with very low latency (especially when compared to "shopping cart" systems like NCEI). http://docs.aws.amazon.com/AmazonS3/latest/dev/Welcome.html
#
# There are many tools that can be used to interact with S3 stores or "Buckets". One tool in Python is Boto.
# From the website: http://boto3.readthedocs.io/en/latest/
#
# "Boto is the Amazon Web Services (AWS) SDK for Python, which allows Python developers to write software that makes use of Amazon services like S3 and EC2. Boto provides an easy to use, object-oriented API as well as low-level direct service access."

# %%
#lets start with some imports

#Py-ART, simply the best sowftware around.. Give those guys a grant
import pyart

#Boto3 is the AWS SDK
import boto3

#botocore contains core configuration utilities for boto2 and boto3
from botocore.handlers import disable_signing

#Tempory files in Python.. A very useful module
import tempfile

#datetime modules.. very handy!
from datetime import datetime

#timezone info
import pytz

#plotting
from matplotlib import pyplot as plt

#plotting on a maop
import cartopy
# %matplotlib inline
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119
# /Users/scollis/anaconda3/envs/pyart-2018/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# You can use Boto and S3 to store all kinds of data! open or closed. In fact Amazon has some very sophisticated methods to set rules.. But the real game changer for the radar community came with the CRADA between Amazon, NOAA and Unidata in putting all NEXRAD data into an S3 Bucket [1].

# %% [markdown]
# The NEXRAD Level II archive data is hosted in the “noaa-nexrad-level2” Amazon S3 bucket in S3’s US East region. The address for the public bucket is:
#
# http://noaa-nexrad-level2.s3.amazonaws.com
#
# https://noaa-nexrad-level2.s3.amazonaws.com
#
# Each volume scan file is its own object in Amazon S3. The basic data format is the following:
#
# `/<Year>/<Month>/<Day>/<NEXRAD Station>/<filename>`
#
# All files in the archive use the same compressed format (.gz). The data file names are, for example, KAKQ20010101_080138.gz. The file naming convention is:
#
# GGGGYYYYMMDD_TTTTTT
#
# Where:
#
# GGGG = Ground station ID (map of ground stations) YYYY = year MM = month DD = day TTTTTT = time when data started to be collected (GMT)
#
# Note that the 2015 files have an additional field on the file name. It adds “_V06” to the end of the file name. An example is KABX20150303_001050_V06.gz.

# %%
# So we start with bucket neame
bucket = "noaa-nexrad-level2"
# Create a s3 "client"
s3 = boto3.resource('s3')
# Set it to unsigned 
s3.meta.client.meta.events.register('choose-signer.s3.*', disable_signing)

# %%
#So now we connect to the bucket with the radar data
aws_radar = s3.Bucket(bucket)

# %% [markdown]
# Now.. indexing the whole bucket would be stupid.. lets do the math: 150 radars, ~6 files per hour, 15 (plus) years that's 324,000 files. Fortunately Boto has some nice indexing utilities.
#
# Buckets contain objects. The objects can be used to do and find out a whole bunch of things.. We are going to use the objects method of out bucket resource to only return objects from the 20th of may 2011 from the vance radar.

# %%
for obj in aws_radar.objects.filter(Prefix='2011/05/20/KVNX/'):
    print('{0}:{1}'.format(aws_radar.name, obj.key))
# Out:
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_000023_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_000442_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_000901_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_001320_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_001740_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_002201_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_002620_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_003040_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_003459_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_003918_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_004338_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_004758_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_005219_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_005639_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_010100_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_010520_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_010939_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_011358_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_011818_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_012438_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_012857_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_013318_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_013737_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_014157_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_014616_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_015036_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_015456_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_015915_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_020336_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_020756_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_021216_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_021636_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_022055_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_022515_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_022936_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_023355_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_023814_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_024233_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_024654_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_025113_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_025532_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_025952_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_030412_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_030831_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_031251_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_031710_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_032129_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_032549_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_033009_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_033428_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_033848_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_034307_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_034727_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_035147_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_035607_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_040026_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_040447_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_040906_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_041326_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_041746_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_042205_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_042624_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_043044_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_043504_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_043924_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_044343_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_044804_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_045225_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_045645_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_050105_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_050525_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_050945_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_051404_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_051824_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_052243_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_052702_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_053122_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_053541_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_054001_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_054420_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_054840_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_055259_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_055718_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_060138_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_060557_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_061016_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_061436_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_061856_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_062315_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_062734_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_063155_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_063615_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_064035_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_064455_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_064915_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_065334_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_065753_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_070212_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_070632_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_071051_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_071512_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_071933_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_072352_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_072811_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_073231_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_073651_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_074111_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_074531_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_074952_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_075412_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_075832_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_080253_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_080713_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_081133_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_081554_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_082014_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_082435_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_082854_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_083314_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_083734_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_084153_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_084612_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_085033_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_085453_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_085912_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_090333_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_090753_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_091212_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_091632_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_092052_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_092709_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_093128_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_093548_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_094009_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_094429_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_094849_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_095308_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_095727_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_100147_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_100608_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_101028_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_101447_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_101906_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_102327_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_102747_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_103207_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_103628_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_104047_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_104507_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_104928_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_105349_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_105809_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_110230_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_110651_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_111111_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_111530_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_111951_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_112410_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_112830_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_113251_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_113710_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_114130_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_114550_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_115011_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_115431_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_115851_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_120311_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_120731_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_121150_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_121611_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_122030_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_122452_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_122911_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_123331_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_123751_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_124211_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_124631_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_125052_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_125511_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_125931_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_130352_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_130812_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_131232_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_131651_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_132111_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_132532_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_132952_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_133412_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_133833_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_134253_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_134713_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_135134_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_135554_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_140014_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_140434_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_140854_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_141314_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_141735_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_142157_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_142617_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_143037_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_143457_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_143918_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_144338_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_144758_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_145217_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_145638_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_150058_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_150519_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_150940_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_151400_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_151819_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_152238_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_152659_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_153119_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_153539_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_154001_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_154420_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_154839_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_155300_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_155758_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_160256_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_160755_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_161253_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_161751_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_162251_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_162750_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_163248_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_163746_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_164245_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_164743_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_165241_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_165740_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_170238_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_170737_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_171235_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_171733_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_172234_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_172929_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_173428_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_173927_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_174425_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_174923_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_175424_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_175922_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_180420_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_180920_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_181418_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_181916_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_182415_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_182915_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_183413_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_183913_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_184412_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_184910_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_185409_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_185908_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_190406_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_190904_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_191403_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_191902_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_192343_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_192826_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_193307_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_193748_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_194231_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_194712_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_195153_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_195634_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_200116_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_200557_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_201039_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_201521_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_202002_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_202445_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_202927_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_203409_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_203850_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_204332_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_204814_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_205255_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_205736_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_210220_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_210701_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_211142_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_211624_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_212105_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_212546_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_213028_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_213509_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_213951_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_214434_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_214916_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_215357_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_215838_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_220320_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_220801_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_221245_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_221726_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_222207_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_222649_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_223131_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_223613_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_224055_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_224537_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_225019_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_225500_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_225942_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_230423_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_230905_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_231348_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_231829_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_232311_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_232752_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_233235_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_233716_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_234158_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_234641_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_235122_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/KVNX20110520_235603_V06.gz
# noaa-nexrad-level2:2011/05/20/KVNX/NWS_NEXRAD_NXL2LG_KVNX_20110520000000_20110520075959.tar
# noaa-nexrad-level2:2011/05/20/KVNX/NWS_NEXRAD_NXL2LG_KVNX_20110520080000_20110520155959.tar
# noaa-nexrad-level2:2011/05/20/KVNX/NWS_NEXRAD_NXL2LG_KVNX_20110520160000_20110520235959.tar

# %% [markdown]
# We can also dump all the keys into a list

# %%
my_list_of_keys = [this_object.key for this_object in aws_radar.objects.filter(Prefix='2011/05/20/KVNX/')]
print(my_list_of_keys[1])
# Out:
# 2011/05/20/KVNX/KVNX20110520_000442_V06.gz

# %% [markdown]
# The strptime method of datetime provides a nice way to turn the stings (keys) into datetime objects.. We also make use of Python's exception handling systems for strings that do not match the pattern

# %%
#lets test it one one of the keys
my_datetime = datetime.strptime(my_list_of_keys[1][20:35], '%Y%m%d_%H%M%S')
print(my_datetime)

#now make an empty list to populated with the datetimes matching
my_list_of_datetimes = []

#loop over all the contents of the bucket with the prefix
for obj in aws_radar.objects.filter(Prefix='2011/05/20/KVNX/'):
    try:
        my_list_of_datetimes.append(datetime.strptime(obj.key[20:35], '%Y%m%d_%H%M%S'))
    except ValueError:
        pass #usually a tar file left in the bucket
# Out:
# 2011-05-20 00:04:42

# %% [markdown]
# Now we want to be able to search for a particular date time in the list.. This is a very handy helper function!

# %%
def nearest(items, pivot):
    return min(items, key=lambda x: abs(x - pivot))

# %%
#lets see if we can find the key for 11Z on the 5th of may 2011
desired_time = datetime(2011,5,20,11,0)

#find the nearest datetime
my_nearest = nearest(my_list_of_datetimes, desired_time)

print('nearest: ', my_nearest, ' desired: ', desired_time)

#find the index of the nearest
print('index: ', my_list_of_datetimes.index(my_nearest))

#find the key of the nearest datetime
print('key: ', my_list_of_keys[my_list_of_datetimes.index(my_nearest)])
# Out:
# nearest:  2011-05-20 10:58:09  desired:  2011-05-20 11:00:00
# index:  151
# key:  2011/05/20/KVNX/KVNX20110520_105809_V06.gz

# %% [markdown]
# ALLRIGHT! Now lets take all we have learned to make a function that can search AWS S3 for the correct key for any radar and any date!

# %%
def find_my_key(radar_name, desired_datetime):
    """
    Find the key in Amazon s3 corresponding to a particular radar site and 
    datetime
    
    Parameters
    ----------
    radar_name : str
        Four letter radar name
    desired_datetime : datetime
        The date time desired
    Returns
    -------
    my_key : string
        string matching the key for the radar file on AWS s3
    """
    
    bucket = "noaa-nexrad-level2"
    # Create a s3 "client"
    s3 = boto3.resource('s3')
    # Set it to unsigned 
    s3.meta.client.meta.events.register('choose-signer.s3.*', disable_signing)
    target_string = datetime.strftime(desired_datetime, '%Y/%m/%d/'+radar_name)
    my_list_of_keys = [this_object.key for this_object in aws_radar.objects.filter(Prefix=target_string)]
    my_list_of_datetimes = []
    for obj in aws_radar.objects.filter(Prefix=target_string):
        try:
            my_list_of_datetimes.append(datetime.strptime(obj.key[20:35], '%Y%m%d_%H%M%S'))
        except ValueError:
            pass #usually a tar file left in the bucket
    my_nearest = nearest(my_list_of_datetimes, desired_datetime)
    my_key = my_list_of_keys[my_list_of_datetimes.index(my_nearest)]
    return my_key

# %% [markdown]
# Lets take it for a spin!

# %%
print(find_my_key('KLOT', datetime(2011,1,1,20,15)))
print(find_my_key('KILX', datetime.utcnow()))
print(find_my_key('TJUA', datetime(2017,9,20,9,0)))
# Out:
# 2011/01/01/KLOT/KLOT20110101_201844_V03.gz
# 2018/03/07/KILX/KILX20180307_185211_V06
# 2017/09/20/TJUA/TJUA20170920_085854_V06

# %% [markdown]
# Ok.. This is pretty boring! Where is the data?! Fortunately Boto3 makes it trivial to download the data with the method:
#
# ```s3.Bucket.download_file(key, localfilename)```
#
# But we do not want to play around with naming files and all that jazz so lets use Python's awesome tempfile module!

# %%
#Lets look at Hurricane Maria
maria_datetime = datetime(2017,9,20,9,0)

#grab the key for Maria
my_key = find_my_key('TJUA', maria_datetime)
print(my_key)

#create a temporary named file
localfile = tempfile.NamedTemporaryFile()

#fetch the data from AWS S3
aws_radar.download_file(my_key, localfile.name)

#read that file into Py-ART!
radar = pyart.io.read(localfile.name)
# Out:
# 2017/09/20/TJUA/TJUA20170920_085854_V06

# %%
#Sweep we want to plot
sweep = 0

#Get the date at the start of collection
index_at_start = radar.sweep_start_ray_index['data'][sweep]
time_at_start_of_radar = pyart.io.cfradial.netCDF4.num2date(radar.time['data'][index_at_start], 
                                  radar.time['units'])

#make a nice time stamp
pacific = pytz.timezone('US/Eastern')
local_time = pacific.fromutc(time_at_start_of_radar)
fancy_date_string = local_time.strftime('%A %B %d at %I:%M %p %Z')
print(fancy_date_string)
# Out:
# Wednesday September 20 at 04:58 AM EDT

# %%
#Set up our figure
fig = plt.figure(figsize = [10,8])

#create a Cartopy Py-ART display object
display = pyart.graph.RadarMapDisplayCartopy(radar)

#get center of the display for the projection
lat_0 = display.loc[0]
lon_0 = display.loc[1]

# Main difference from Basemap! 
#Cartopy forces you to select a projection first!
projection = cartopy.crs.Mercator(
                central_longitude=lon_0,
                min_latitude=15, max_latitude=20)

title = 'TJUA \n' + fancy_date_string

#plot a PPI! add coastline at 10m resolution
display.plot_ppi_map(
    'reflectivity', sweep, colorbar_flag=True,
    title=title,
    projection=projection,
    min_lon=-67, max_lon=-65, min_lat=17, max_lat=19,
    vmin=-12, vmax=64, resolution='10m', 
    cmap=pyart.graph.cm.LangRainbow12)

# Mark the radar
display.plot_point(lon_0, lat_0, label_text='TJUA')

# Plot some lat and lon lines
gl = display.ax.gridlines(draw_labels=True,
                          linewidth=2, color='gray', alpha=0.5, linestyle='--')
gl.xlabels_top = False
gl.ylabels_right = False

# %% [markdown]
# **Sorry for the Colorblind unfriendly colormap.. New colormaps coming in Py-ART 1.10 - Dali in September**

# %%
#Now it is your turn
#Grab and plot the data for Hurricane Sandy from KDOX at 2012-10-29-20:00Z 
#set a bounding box min_lon=-78, max_lon=-73.5, min_lat=37, max_lat=40

# %%
#Your answer

# %%
#run to get our answer!
# %load sandy_answer.py

# %% [markdown]
# [1] Ansari, S., S. Del Greco, E. Kearns, O. Brown, S. Wilkins, M. Ramamurthy, J. Weber, R. May, J. Sundwall, J. Layton, A. Gold, A. Pasch, and V. Lakshmanan, 0: Unlocking the potential of NEXRAD data through NOAA’s Big Data Partnership. Bull. Amer. Meteor. Soc., 0, https://doi.org/10.1175/BAMS-D-16-0021.1
